# %% [markdown]
# # Importando bibliotecas e visualizando o dataset

# %%
import pandas as pd
import numpy as np
import keras
from matplotlib import pyplot as plt

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
# Out:
# Using TensorFlow backend.

# %%
data = pd.read_csv('weatherAUS.csv')
data.head(10)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# 5  2008-12-06   Albury     14.6     29.7       0.2          NaN       NaN
# 6  2008-12-07   Albury     14.3     25.0       0.0          NaN       NaN
# 7  2008-12-08   Albury      7.7     26.7       0.0          NaN       NaN
# 8  2008-12-09   Albury      9.7     31.9       0.0          NaN       NaN
# 9  2008-12-10   Albury     13.1     30.1       1.4          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
# 3          NE           24.0         SE  ...        16.0       1017.6
# 4           W           41.0        ENE  ...        33.0       1010.8
# 5         WNW           56.0          W  ...        23.0       1009.2
# 6           W           50.0         SW  ...        19.0       1009.6
# 7           W           35.0        SSE  ...        19.0       1013.4
# 8         NNW           80.0         SE  ...         9.0       1008.9
# 9           W           28.0          S  ...        27.0       1007.0
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 0       1007.1       8.0       NaN     16.9     21.8         No      0.0
# 1       1007.8       NaN       NaN     17.2     24.3         No      0.0
# 2       1008.7       NaN       2.0     21.0     23.2         No      0.0
# 3       1012.8       NaN       NaN     18.1     26.5         No      1.0
# 4       1006.0       7.0       8.0     17.8     29.7         No      0.2
# 5       1005.4       NaN       NaN     20.6     28.9         No      0.0
# 6       1008.2       1.0       NaN     18.1     24.6         No      0.0
# 7       1010.1       NaN       NaN     16.3     25.5         No      0.0
# 8       1003.6       NaN       NaN     18.3     30.2         No      1.4
# 9       1005.7       NaN       NaN     20.1     28.2        Yes      0.0
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
# 5            No
# 6            No
# 7            No
# 8           Yes
# 9            No
#
# [10 rows x 24 columns]

# %%
'Linhas: {} | Colunas: {}'.format(data.shape[0], data.shape[1])
# Out:
# 'Linhas: 142193 | Colunas: 24'

# %% [markdown]
# # Removendo dados nulos

# %%
data = data.dropna()
data.head(10)
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 5939  2009-01-01    Cobar     17.9     35.2       0.0         12.0      12.3
# 5940  2009-01-02    Cobar     18.4     28.9       0.0         14.8      13.0
# 5942  2009-01-04    Cobar     19.4     37.6       0.0         10.8      10.6
# 5943  2009-01-05    Cobar     21.9     38.4       0.0         11.4      12.2
# 5944  2009-01-06    Cobar     24.2     41.0       0.0         11.2       8.4
# 5945  2009-01-07    Cobar     27.1     36.1       0.0         13.0       0.0
# 5946  2009-01-08    Cobar     23.3     34.0       0.0          9.8      12.6
# 5947  2009-01-09    Cobar     16.1     34.2       0.0         14.6      13.2
# 5948  2009-01-10    Cobar     19.0     35.5       0.0         12.0      12.3
# 5949  2009-01-11    Cobar     19.7     35.5       0.0         11.0      12.7
#
#      WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 5939         SSW           48.0        ENE  ...        13.0       1006.3
# 5940           S           37.0        SSE  ...         8.0       1012.9
# 5942         NNE           46.0        NNE  ...        22.0       1012.3
# 5943         WNW           31.0        WNW  ...        22.0       1012.7
# 5944         WNW           35.0         NW  ...        15.0       1010.7
# 5945           N           43.0          N  ...        19.0       1007.7
# 5946         SSW           41.0          S  ...        15.0       1011.3
# 5947          SE           37.0         SE  ...         9.0       1013.3
# 5948         ENE           48.0        ENE  ...        28.0       1008.3
# 5949          NE           41.0        NNE  ...        14.0       1007.9
#
#       Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 5939       1004.4       2.0       5.0     26.6     33.4         No      0.0
# 5940       1012.1       1.0       1.0     20.3     27.0         No      0.0
# 5942       1009.2       1.0       6.0     28.7     34.9         No      0.0
# 5943       1009.1       1.0       5.0     29.1     35.6         No      0.0
# 5944       1007.4       1.0       6.0     33.6     37.6         No      0.0
# 5945       1007.4       8.0       8.0     30.7     34.3         No      0.0
# 5946       1009.9       3.0       1.0     25.0     31.5         No      0.0
# 5947       1009.2       1.0       1.0     20.7     32.8         No      0.0
# 5948       1004.0       1.0       5.0     23.4     33.3         No      0.0
# 5949       1005.8       1.0       5.0     24.0     33.6         No      0.0
#
#       RainTomorrow
# 5939            No
# 5940            No
# 5942            No
# 5943            No
# 5944            No
# 5945            No
# 5946            No
# 5947            No
# 5948            No
# 5949            No
#
# [10 rows x 24 columns]

# %%
'Linhas: {} | Colunas: {}'.format(data.shape[0], data.shape[1])
# Out:
# 'Linhas: 56420 | Colunas: 24'

# %%
fig, ax = plt.subplots(1,1, figsize=(8, 5))

counts = data['RainTomorrow'].value_counts()
counts.plot.bar(color='green', ax=ax, grid=False)

# %% [markdown]
# # Lidando com variáveis categóricas

# %%
rain_tomorrow = list(data.RainTomorrow)

yes, no = 0, 0

for instance in rain_tomorrow:
    if (instance == "Yes"):
        yes += 1
    no += 1
    
print("yes:", yes)
print("no:", no)
# Out:
# yes: 12427
# no: 56420

# %%
# Antes da transformação
print('Wind gust direction:')
data.WindGustDir.unique()
# Out:
# Wind gust direction:
# array(['SSW', 'S', 'NNE', 'WNW', 'N', 'SE', 'ENE', 'NE', 'E', 'SW', 'W',
#        'WSW', 'NNW', 'ESE', 'SSE', 'NW'], dtype=object)

# %%
# Antes da transformação
print('Wind gust direction at 9am:')
data.WindDir9am.unique()
# Out:
# Wind gust direction at 9am:
# array(['ENE', 'SSE', 'NNE', 'WNW', 'NW', 'N', 'S', 'SE', 'NE', 'W', 'SSW',
#        'E', 'NNW', 'ESE', 'WSW', 'SW'], dtype=object)

# %%
# Antes da transformação
print('Rain Today:')
data.RainToday.unique()
# Out:
# Rain Today:
# array(['No', 'Yes'], dtype=object)

# %%
# Antes da transformação
print('Rain Tomorrow:')
data.RainTomorrow.unique()
# Out:
# Rain Tomorrow:
# array(['No', 'Yes'], dtype=object)

# %%
label_encoder = LabelEncoder()

data.WindGustDir = label_encoder.fit_transform(data.WindGustDir)
data.WindDir9am = label_encoder.fit_transform(data.WindDir9am)
data.RainToday = label_encoder.fit_transform(data.RainToday)
data.RainTomorrow = label_encoder.fit_transform(data.RainTomorrow)

# %%
# Depois da transformação
print('Wind gust direction:')
data.WindGustDir.unique()
# Out:
# Wind gust direction:
# array([11,  8,  5, 14,  3,  9,  1,  4,  0, 12, 13, 15,  6,  2, 10,  7])

# %%
# Depois da transformação
print('Wind gust direction at 9am:')
data.WindDir9am.unique()
# Out:
# Wind gust direction at 9am:
# array([ 1, 10,  5, 14,  7,  3,  8,  9,  4, 13, 11,  0,  6,  2, 15, 12])

# %%
# Depois da transformação
print('Rain today:')
data.RainToday.unique()
# Out:
# Rain today:
# array([0, 1])

# %%
# Depois da transformação
print('Rain tomorrow:')
data.RainTomorrow.unique()
# Out:
# Rain tomorrow:
# array([0, 1])

# %%
data.head(10)
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 5939  2009-01-01    Cobar     17.9     35.2       0.0         12.0      12.3
# 5940  2009-01-02    Cobar     18.4     28.9       0.0         14.8      13.0
# 5942  2009-01-04    Cobar     19.4     37.6       0.0         10.8      10.6
# 5943  2009-01-05    Cobar     21.9     38.4       0.0         11.4      12.2
# 5944  2009-01-06    Cobar     24.2     41.0       0.0         11.2       8.4
# 5945  2009-01-07    Cobar     27.1     36.1       0.0         13.0       0.0
# 5946  2009-01-08    Cobar     23.3     34.0       0.0          9.8      12.6
# 5947  2009-01-09    Cobar     16.1     34.2       0.0         14.6      13.2
# 5948  2009-01-10    Cobar     19.0     35.5       0.0         12.0      12.3
# 5949  2009-01-11    Cobar     19.7     35.5       0.0         11.0      12.7
#
#       WindGustDir  WindGustSpeed  WindDir9am  ... Humidity3pm  Pressure9am  \
# 5939           11           48.0           1  ...        13.0       1006.3
# 5940            8           37.0          10  ...         8.0       1012.9
# 5942            5           46.0           5  ...        22.0       1012.3
# 5943           14           31.0          14  ...        22.0       1012.7
# 5944           14           35.0           7  ...        15.0       1010.7
# 5945            3           43.0           3  ...        19.0       1007.7
# 5946           11           41.0           8  ...        15.0       1011.3
# 5947            9           37.0           9  ...         9.0       1013.3
# 5948            1           48.0           1  ...        28.0       1008.3
# 5949            4           41.0           5  ...        14.0       1007.9
#
#       Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 5939       1004.4       2.0       5.0     26.6     33.4          0      0.0
# 5940       1012.1       1.0       1.0     20.3     27.0          0      0.0
# 5942       1009.2       1.0       6.0     28.7     34.9          0      0.0
# 5943       1009.1       1.0       5.0     29.1     35.6          0      0.0
# 5944       1007.4       1.0       6.0     33.6     37.6          0      0.0
# 5945       1007.4       8.0       8.0     30.7     34.3          0      0.0
# 5946       1009.9       3.0       1.0     25.0     31.5          0      0.0
# 5947       1009.2       1.0       1.0     20.7     32.8          0      0.0
# 5948       1004.0       1.0       5.0     23.4     33.3          0      0.0
# 5949       1005.8       1.0       5.0     24.0     33.6          0      0.0
#
#       RainTomorrow
# 5939             0
# 5940             0
# 5942             0
# 5943             0
# 5944             0
# 5945             0
# 5946             0
# 5947             0
# 5948             0
# 5949             0
#
# [10 rows x 24 columns]

# %% [markdown]
# # Normalização dos dados

# %%
scaler = StandardScaler()

x_train = data[[
    'MinTemp',
    'MaxTemp',
    'Rainfall',
    'Evaporation',
    'Sunshine',
    'WindGustSpeed',
    'Humidity3pm',
    'Pressure9am',
    'Pressure3pm',
    'Cloud9am',
    'Cloud3pm',
    'Temp9am',
    'Temp3pm',
    'RISK_MM',
]]

scaled = scaler.fit_transform(x_train)

# %%
names = [
    'MinTemp',
    'MaxTemp',
    'Rainfall',
    'Evaporation',
    'Sunshine',
    'WindGustSpeed',
    'Humidity3pm',
    'Pressure9am',
    'Pressure3pm',
    'Cloud9am',
    'Cloud3pm',
    'Temp9am',
    'Temp3pm',
    'RISK_MM',
]
date = list(data.Date)
raintd = list(data.RainToday)
raintm = list(data.RainTomorrow)

data_scaled = pd.DataFrame(scaled, columns=names)

data_scaled.insert(0, 'Date', date)
data_scaled.insert(15, 'RainToday', raintd)
data_scaled.insert(16, 'RainTomorrow', raintm)
data_scaled.head(10)
# Out:
#          Date   MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2009-01-01  0.691208  1.575298 -0.303702     1.757691  1.214537
# 1  2009-01-02  0.769131  0.671504 -0.303702     2.515216  1.400800
# 2  2009-01-04  0.924976  1.919600 -0.303702     1.433038  0.762183
# 3  2009-01-05  1.314588  2.034368 -0.303702     1.595364  1.187928
# 4  2009-01-06  1.673032  2.407362 -0.303702     1.541255  0.176784
# 5  2009-01-07  2.124982  1.704411 -0.303702     2.028236 -2.058376
# 6  2009-01-08  1.532771  1.403147 -0.303702     1.162493  1.294364
# 7  2009-01-09  0.410687  1.431838 -0.303702     2.461107  1.454018
# 8  2009-01-10  0.862638  1.618336 -0.303702     1.757691  1.214537
# 9  2009-01-11  0.971729  1.618336 -0.303702     1.487147  1.320973
#
#    WindGustSpeed  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# 0       0.534126    -1.812261    -1.583303    -1.513002 -0.801428  0.254411
# 1      -0.290764    -2.059824    -0.628068    -0.392322 -1.158937 -1.256603
# 2       0.384146    -1.366647    -0.714907    -0.814396 -1.158937  0.632165
# 3      -0.740704    -1.366647    -0.657014    -0.828951 -1.158937  0.254411
# 4      -0.440744    -1.713236    -0.946479    -1.076373 -1.158937  0.632165
# 5       0.159176    -1.515185    -1.380677    -1.076373  1.343622  1.387672
# 6       0.009196    -1.713236    -0.859640    -0.712516 -0.443920 -1.256603
# 7      -0.290764    -2.010312    -0.570175    -0.814396 -1.158937 -1.256603
# 8       0.534126    -1.069571    -1.293837    -1.571219 -1.158937  0.254411
# 9       0.009196    -1.762748    -1.351730    -1.309242 -1.158937  0.254411
#
#     Temp9am   Temp3pm   RISK_MM  RainToday  RainTomorrow
# 0  1.278186  1.563621 -0.268783          0             0
# 1  0.318980  0.627467 -0.268783          0             0
# 2  1.597921  1.783032 -0.268783          0             0
# 3  1.658823  1.885424 -0.268783          0             0
# 4  2.343970  2.177972 -0.268783          0             0
# 5  1.902431  1.695268 -0.268783          0             0
# 6  1.034578  1.285700 -0.268783          0             0
# 7  0.379882  1.475856 -0.268783          0             0
# 8  0.790970  1.548993 -0.268783          0             0
# 9  0.882323  1.592876 -0.268783          0             0

# %% [markdown]
# # Resampling

# %%
target_count = data_scaled.RainTomorrow.value_counts()

print('Class 0:', target_count[0])
print('Class 1:', target_count[1])
print('Proportion:', round(target_count[0] / target_count[1], 2), ': 1')

target_count.plot(kind='bar', title='Count (Rain tomorrow)');
# Out:
# Class 0: 43993
# Class 1: 12427
# Proportion: 3.54 : 1

# %%
# Contando as classes
count_class_0, count_class_1 = data_scaled.RainTomorrow.value_counts()

# Divide por classes
df_class_0 = data_scaled[data_scaled['RainTomorrow'] == 0]
df_class_1 = data_scaled[data_scaled['RainTomorrow'] == 1]

# %%
df_class_1_over = df_class_1.sample(count_class_0, replace=True)
df_test_over = pd.concat([df_class_0, df_class_1_over], axis=0)

print('Random over-sampling:')
print(df_test_over.RainTomorrow.value_counts())

# 'df_test_over' é nosso novo dataset com
# instâncias igualadas pela classe majoritária
df_test_over.RainTomorrow.value_counts().plot(kind='bar', title='Count (Rain tomorrow)');
# Out:
# Random over-sampling:
# 1    43993
# 0    43993
# Name: RainTomorrow, dtype: int64

# %% [markdown]
# # Treinando MLP

# %%
'Linhas: {} | Colunas: {}'.format(df_test_over.shape[0], df_test_over.shape[1])
# Out:
# 'Linhas: 87986 | Colunas: 17'

# %%
X = df_test_over.loc[:,[
    'MinTemp',
    'MaxTemp',
    'Rainfall',
    'Evaporation',
    'Sunshine',
    'WindGustSpeed',
    'Humidity3pm',
    'Pressure9am',
    'Pressure3pm',
    'Cloud9am',
    'Cloud3pm',
    'Temp9am',
    'Temp3pm',
    'RISK_MM'
]]
y = df_test_over.loc[:,['RainTomorrow']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 100)

# %%
classifier = Sequential()

classifier.add(
    Dense(
        units=2,
        activation='relu',
        kernel_initializer='random_normal',
        input_dim=X_train.shape[-1]
    )
)

classifier.add(
    Dense(
        units=4,
        activation='relu',
        kernel_initializer='random_normal',
    )
)

classifier.add(
    Dense(
        units=4,
        activation='relu',
        kernel_initializer='random_normal',
    )
)

classifier.add(
    Dense(
        units=1,
        activation='relu',
        kernel_initializer='random_normal',
    )
)

# %%
classifier.compile(optimizer='adam',loss='mean_squared_error', metrics=['accuracy'])

# %%
run = classifier.fit(X_train,y_train, batch_size=20, epochs=50, validation_data=(X_test, y_test))
# Out:
# Train on 61590 samples, validate on 26396 samples
# Epoch 1/50
# 61590/61590 [==============================] - 4s 68us/step - loss: 0.1401 - acc: 0.8050 - val_loss: 0.1407 - val_acc: 0.8066
# Epoch 2/50
# 61590/61590 [==============================] - 4s 68us/step - loss: 0.1402 - acc: 0.8055 - val_loss: 0.1416 - val_acc: 0.8094
# Epoch 3/50
# 61590/61590 [==============================] - 5s 85us/step - loss: 0.1402 - acc: 0.8050 - val_loss: 0.1413 - val_acc: 0.8075
# Epoch 4/50
# 61590/61590 [==============================] - 4s 69us/step - loss: 0.1402 - acc: 0.8061 - val_loss: 0.1413 - val_acc: 0.8083
# Epoch 5/50
# 61590/61590 [==============================] - 4s 68us/step - loss: 0.1402 - acc: 0.8057 - val_loss: 0.1408 - val_acc: 0.8073
# Epoch 6/50
# 61590/61590 [==============================] - 5s 75us/step - loss: 0.1402 - acc: 0.8047 - val_loss: 0.1415 - val_acc: 0.8082
# Epoch 7/50
# 61590/61590 [==============================] - 5s 77us/step - loss: 0.1402 - acc: 0.8044 - val_loss: 0.1408 - val_acc: 0.8063
# Epoch 8/50
# 61590/61590 [==============================] - 4s 69us/step - loss: 0.1401 - acc: 0.8052 - val_loss: 0.1409 - val_acc: 0.8061
# Epoch 9/50
# 61590/61590 [==============================] - 4s 69us/step - loss: 0.1402 - acc: 0.8054 - val_loss: 0.1407 - val_acc: 0.8065
# Epoch 10/50
# 61590/61590 [==============================] - 4s 70us/step - loss: 0.1401 - acc: 0.8056 - val_loss: 0.1410 - val_acc: 0.8083
# Epoch 11/50
# 61590/61590 [==============================] - 4s 69us/step - loss: 0.1402 - acc: 0.8061 - val_loss: 0.1413 - val_acc: 0.8070
# Epoch 12/50
# 61590/61590 [==============================] - 4s 68us/step - loss: 0.1401 - acc: 0.8056 - val_loss: 0.1411 - val_acc: 0.8058
# Epoch 13/50
# 61590/61590 [==============================] - 4s 69us/step - loss: 0.1401 - acc: 0.8049 - val_loss: 0.1407 - val_acc: 0.8080
# Epoch 14/50
# 61590/61590 [==============================] - 5s 74us/step - loss: 0.1401 - acc: 0.8055 - val_loss: 0.1410 - val_acc: 0.8070
# Epoch 15/50
# 61590/61590 [==============================] - 5s 79us/step - loss: 0.1401 - acc: 0.8052 - val_loss: 0.1427 - val_acc: 0.8058
# Epoch 16/50
# 61590/61590 [==============================] - 5s 83us/step - loss: 0.1402 - acc: 0.8057 - val_loss: 0.1411 - val_acc: 0.8071
# Epoch 17/50
# 61590/61590 [==============================] - 5s 74us/step - loss: 0.1401 - acc: 0.8056 - val_loss: 0.1406 - val_acc: 0.8076
# Epoch 18/50
# 61590/61590 [==============================] - 4s 69us/step - loss: 0.1401 - acc: 0.8058 - val_loss: 0.1417 - val_acc: 0.8042
# Epoch 19/50
# 61590/61590 [==============================] - 5s 78us/step - loss: 0.1400 - acc: 0.8051 - val_loss: 0.1444 - val_acc: 0.8072
# Epoch 20/50
# 61590/61590 [==============================] - 4s 70us/step - loss: 0.1402 - acc: 0.8053 - val_loss: 0.1406 - val_acc: 0.8094
# Epoch 21/50
# 61590/61590 [==============================] - 4s 71us/step - loss: 0.1402 - acc: 0.8049 - val_loss: 0.1412 - val_acc: 0.8067
# Epoch 22/50
# 61590/61590 [==============================] - 5s 81us/step - loss: 0.1402 - acc: 0.8053 - val_loss: 0.1406 - val_acc: 0.8089
# Epoch 23/50
# 61590/61590 [==============================] - 4s 69us/step - loss: 0.1401 - acc: 0.8053 - val_loss: 0.1406 - val_acc: 0.8079
# Epoch 24/50
# 61590/61590 [==============================] - 5s 78us/step - loss: 0.1401 - acc: 0.8049 - val_loss: 0.1409 - val_acc: 0.8085
# Epoch 25/50
# 61590/61590 [==============================] - 4s 68us/step - loss: 0.1401 - acc: 0.8055 - val_loss: 0.1405 - val_acc: 0.8069
# Epoch 26/50
# 61590/61590 [==============================] - 4s 69us/step - loss: 0.1344 - acc: 0.8125 - val_loss: 0.1122 - val_acc: 0.8439
# Epoch 27/50
# 61590/61590 [==============================] - 4s 68us/step - loss: 0.0521 - acc: 0.9361 - val_loss: 0.0125 - val_acc: 0.9916
# Epoch 28/50
# 61590/61590 [==============================] - 4s 67us/step - loss: 0.0115 - acc: 0.9914 - val_loss: 0.0076 - val_acc: 0.9928
# Epoch 29/50
# 61590/61590 [==============================] - 4s 68us/step - loss: 0.0076 - acc: 0.9936 - val_loss: 0.0056 - val_acc: 0.9928
# Epoch 30/50
# 61590/61590 [==============================] - 4s 68us/step - loss: 0.0130 - acc: 0.9878 - val_loss: 0.0450 - val_acc: 0.9908
# Epoch 31/50
# 61590/61590 [==============================] - 4s 70us/step - loss: 0.0078 - acc: 0.9932 - val_loss: 0.0052 - val_acc: 0.9936
# Epoch 32/50
# 61590/61590 [==============================] - 4s 69us/step - loss: 0.0143 - acc: 0.9865 - val_loss: 0.0047 - val_acc: 0.9978
# Epoch 33/50
# 61590/61590 [==============================] - 4s 69us/step - loss: 0.0079 - acc: 0.9929 - val_loss: 0.0417 - val_acc: 0.9508
# Epoch 34/50
# 61590/61590 [==============================] - 4s 68us/step - loss: 0.0087 - acc: 0.9921 - val_loss: 0.0044 - val_acc: 0.9969
# Epoch 35/50
# 61590/61590 [==============================] - 4s 69us/step - loss: 0.0139 - acc: 0.9870 - val_loss: 0.0050 - val_acc: 0.9927
# Epoch 36/50
# 61590/61590 [==============================] - 5s 85us/step - loss: 0.0075 - acc: 0.9932 - val_loss: 0.0047 - val_acc: 0.9947
# Epoch 37/50
# 61590/61590 [==============================] - 4s 71us/step - loss: 0.0085 - acc: 0.9919 - val_loss: 0.0045 - val_acc: 0.9978
# Epoch 38/50
# 61590/61590 [==============================] - 4s 69us/step - loss: 0.0068 - acc: 0.9941 - val_loss: 0.0041 - val_acc: 0.9978
# Epoch 39/50
# 61590/61590 [==============================] - 4s 72us/step - loss: 0.0077 - acc: 0.9929 - val_loss: 0.0041 - val_acc: 0.9964
# Epoch 40/50
# 61590/61590 [==============================] - 5s 79us/step - loss: 0.0162 - acc: 0.9847 - val_loss: 0.0047 - val_acc: 0.9963
# Epoch 41/50
# 61590/61590 [==============================] - 5s 76us/step - loss: 0.0068 - acc: 0.9939 - val_loss: 0.0042 - val_acc: 0.9972
# Epoch 42/50
# 61590/61590 [==============================] - 4s 69us/step - loss: 0.0222 - acc: 0.9799 - val_loss: 0.0042 - val_acc: 0.9947
# Epoch 43/50
# 61590/61590 [==============================] - 4s 70us/step - loss: 0.0058 - acc: 0.9950 - val_loss: 0.0065 - val_acc: 0.9968
# Epoch 44/50
# 61590/61590 [==============================] - 4s 69us/step - loss: 0.0094 - acc: 0.9918 - val_loss: 0.0084 - val_acc: 0.9973
# Epoch 45/50
# 61590/61590 [==============================] - 4s 70us/step - loss: 0.0070 - acc: 0.9936 - val_loss: 0.0041 - val_acc: 0.9978
# Epoch 46/50
# 61590/61590 [==============================] - 4s 70us/step - loss: 0.0093 - acc: 0.9912 - val_loss: 0.0042 - val_acc: 0.9941
# Epoch 47/50
# 61590/61590 [==============================] - 4s 69us/step - loss: 0.0077 - acc: 0.9928 - val_loss: 0.0058 - val_acc: 0.9946
# Epoch 48/50
# 61590/61590 [==============================] - 4s 69us/step - loss: 0.0179 - acc: 0.9835 - val_loss: 0.0039 - val_acc: 0.9975
# Epoch 49/50
# 61590/61590 [==============================] - 4s 68us/step - loss: 0.0069 - acc: 0.9938 - val_loss: 0.0040 - val_acc: 0.9959
# Epoch 50/50
# 61590/61590 [==============================] - 4s 70us/step - loss: 0.0069 - acc: 0.9938 - val_loss: 0.0040 - val_acc: 0.9932

# %%
plt.title('Treino')
plt.grid(True)
plt.plot(run.history['acc'])
plt.show()

# %%
plt.title('Teste')
plt.grid(True)
plt.plot(run.history['val_acc'])
plt.show()
